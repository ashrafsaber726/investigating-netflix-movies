# %% [markdown]
# # Project Description

# %% [markdown]
# ![hq720.jpg](attachment:bcf707d5-78a9-4f1c-9260-2eb367d28479.jpg)

# %% [markdown]
# Netflix! What started in 1997 as a DVD rental service has since exploded into the largest entertainment/media company by market capitalization, boasting over 200 million subscribers as of January 2021.
#
# Given the large number of movies and series available on the platform, it is a perfect opportunity to flex our data manipulation skills and dive into the entertainment industry. Our friend has also been brushing up on their Python skills and has taken a first crack at a CSV file containing Netflix data. For their first order of business, they have been performing some analyses, and they believe that the average duration of movies has been declining.
#
# As evidence of this, they have provided us with the following information. For the years from 2011 to 2020, the average movie durations are 103, 101, 99, 100, 100, 95, 95, 96, 93, and 90, respectively.
#
# If we're going to be working with this data, we know a good place to start would be to probably start working with pandas. But first we'll need to create a DataFrame from scratch. Let's start by creating a Python object covered in Intermediate Python: a dictionary!

# %% [markdown]
# # Import Needed Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Loading dataset

# %%
netflix_df = pd.read_csv('/kaggle/input/netflix-data/netflix_data.csv',index_col=0)
netflix_df.head()
# Out:
#             type  title           director  \
# show_id
# s1       TV Show     3%                NaN
# s2         Movie   7:19  Jorge Michel Grau
# s3         Movie  23:59       Gilbert Chan
# s4         Movie      9        Shane Acker
# s5         Movie     21     Robert Luketic
#
#                                                       cast        country  \
# show_id
# s1       João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# s2       Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# s3       Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# s4       Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# s5       Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#                 date_added  release_year  duration  \
# show_id
# s1         August 14, 2020          2020         4
# s2       December 23, 2016          2016        93
# s3       December 20, 2018          2011        78
# s4       November 16, 2017          2009        80
# s5         January 1, 2020          2008       123
#
#                                                description             genre
# show_id
# s1       In a future where the elite inhabit an island ...  International TV
# s2       After a devastating earthquake hits Mexico Cit...            Dramas
# s3       When an army recruit is found dead, his fellow...     Horror Movies
# s4       In a postapocalyptic world, rag-doll robots hi...            Action
# s5       A brilliant group of students become card-coun...            Dramas

# %% [markdown]
# # Get information about the netflix_df

# %%
netflix_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7787 entries, s1 to s7787
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   type          7787 non-null   object
#  1   title         7787 non-null   object
#  2   director      5398 non-null   object
#  3   cast          7069 non-null   object
#  4   country       7280 non-null   object
#  5   date_added    7777 non-null   object
#  6   release_year  7787 non-null   int64
#  7   duration      7787 non-null   int64
#  8   description   7787 non-null   object
#  9   genre         7787 non-null   object
# dtypes: int64(2), object(8)
# memory usage: 669.2+ KB

# %% [markdown]
# # Some Operations

# %%
# Subset the DataFrame not including type "TV Show"
netflix_subset = netflix_df[netflix_df.type != 'TV Show']
netflix_subset.head()
# Out:
#           type  title           director  \
# show_id
# s2       Movie   7:19  Jorge Michel Grau
# s3       Movie  23:59       Gilbert Chan
# s4       Movie      9        Shane Acker
# s5       Movie     21     Robert Luketic
# s7       Movie    122    Yasir Al Yasiri
#
#                                                       cast        country  \
# show_id
# s2       Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# s3       Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# s4       Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# s5       Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# s7       Amina Khalil, Ahmed Dawood, Tarek Lotfy, Ahmed...          Egypt
#
#                 date_added  release_year  duration  \
# show_id
# s2       December 23, 2016          2016        93
# s3       December 20, 2018          2011        78
# s4       November 16, 2017          2009        80
# s5         January 1, 2020          2008       123
# s7            June 1, 2020          2019        95
#
#                                                description          genre
# show_id
# s2       After a devastating earthquake hits Mexico Cit...         Dramas
# s3       When an army recruit is found dead, his fellow...  Horror Movies
# s4       In a postapocalyptic world, rag-doll robots hi...         Action
# s5       A brilliant group of students become card-coun...         Dramas
# s7       After an awful accident, a couple admitted to ...  Horror Movies

# %%
# Select specific columns
netflix_movies = netflix_df [['title','country','genre','release_year','duration']]
netflix_movies.head()
# Out:
#          title        country             genre  release_year  duration
# show_id
# s1          3%         Brazil  International TV          2020         4
# s2        7:19         Mexico            Dramas          2016        93
# s3       23:59      Singapore     Horror Movies          2011        78
# s4           9  United States            Action          2009        80
# s5          21  United States            Dramas          2008       123

# %%
# Filter duration < 60
short_movies = netflix_movies[netflix_movies['duration'] < 60]
short_movies.head(20)
# Out:
#                                                      title         country  \
# show_id
# s1                                                      3%          Brazil
# s6                                                      46          Turkey
# s12                                                   1983          Poland
# s13                                                   1994          Mexico
# s17                                                 Feb-09             NaN
# s25                    ​SAINT SEIYA: Knights of the Zodiac           Japan
# s27                                               (Un)Well   United States
# s30                                               #blackAF   United States
# s36                                              #Rucker50   United States
# s39                                    แผนร้ายนายเจ้าเล่ห์             NaN
# s46                                                  Şubat          Turkey
# s52                                     100 Days My Prince     South Korea
# s54                                             100 Humans   United States
# s56                    100 Things to do Before High School   United States
# s59                                            100% Hotter  United Kingdom
# s62                                       12 Years Promise     South Korea
# s64                                         13 Reasons Why   United States
# s65                     13 Reasons Why: Beyond the Reasons   United States
# s68      13TH: A Conversation with Oprah Winfrey & Ava ...             NaN
# s81                                             20 Minutes          Turkey
#
#                     genre  release_year  duration
# show_id
# s1       International TV          2020         4
# s6       International TV          2016         1
# s12              Crime TV          2018         1
# s13              Crime TV          2019         1
# s17      International TV          2018         1
# s25          Anime Series          2020         2
# s27            Reality TV          2020         1
# s30           TV Comedies          2020         1
# s36         Documentaries          2016        56
# s39      International TV          2016         1
# s46              Crime TV          2013         1
# s52      International TV          2018         1
# s54            Docuseries          2020         1
# s56         Uncategorized          2014        44
# s59            British TV          2017         1
# s62      International TV          2014         1
# s64              Crime TV          2020         4
# s65              Crime TV          2019         3
# s68         Uncategorized          2017        37
# s81              Crime TV          2013         1

# %%
# Make colors list
colors = []
for index,row in netflix_movies.iterrows():
    if row['genre'] == 'Children' :
        colors.append('green')
    elif row['genre'] == 'Documentaries' :
        colors.append('yellow')
    elif row['genre'] == 'Stand-Up' :
        colors.append('orange')
    else :
        colors.append('red')

# %% [markdown]
# # Visualization

# %%
#Set the figure style
fig = plt.figure(figsize=(12,8))

#Create a scatter plot
plt.scatter(netflix_movies.release_year,netflix_movies.duration,c=colors)

#Create a title and axis labels
plt.xlabel('Release year')
plt.ylabel('Duration (min)')
plt.title("Movie Duration by Year of Release")

#Show the plot
plt.show()

#plt.savefig(sys.stdout.buffer)
#sys.stdout.flush()

# %%
#Are we certain that movies are getting shorter?
answer = "no"
